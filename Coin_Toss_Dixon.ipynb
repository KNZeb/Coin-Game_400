# %%
"""
Zimren Dixon Coin Toss

Write a class named Coin. The Coin class should have the following member variables:
 A string named “sideUp”. The sideUp member variable will hold either “heads” or
“tails” indicating the side of the coin that is facing up.
The Coin class should have the following member functions:
 A void member function named “toss” that simulates the tossing of the coin. When
the toss member function is called, it randomly determines the side of the coin that is
facing up (“heads” or “tails”) and sets the sideUp member variable accordingly.
 A member function named “getSideUp” that returns the value of the sideUp member
variable.

For this project, you will create a game program using the Coin class. The program should have
THREE instances of the Coin class: one representing a quarter, one representing a dime, and one
representing a nickel.
When the game begins, your starting balance is $0.00. During each round of the game, the
program will toss all three coins. When a coin is tossed, the value of the coin is added to your
balance if it lands heads-up. For example, if the quarter lands heads-up, 25 cents is added to
your balance. Nothing is added to your balance for coins that land tails-up. The game is over
when your balance reaches $1.00 or more. If your balance is EXACTLY $1.00 you win the
game. You lose if your balance exceeds $1.00.
Do this in a loop, so that the player may continue to play. After each game play ask the player if
they wish to play again. Once they are done playing, please print out the number of wins and the
number of losses.
During each round: Flip the coins once, somehow let the player know which coins are heads-up
and which are tails-up. Add the new monies to the total. Pause, print out a message to the player
that s/he should hit &lt;Enter&gt; to toss the coins again. Continue in this manner until the player has
either won or lost. At this point, ask the player if they wish to play again, starting over with a
balance of $0.00. """


import random
import time


class Coin:

    quarter = 0 
    dime = 0 
    nickel = 0
    balances = 0.00
    
    
    
    def __init__ (self):
        self.sideUp = ["Tails", "Heads"]
        self.Game_Goings = ["\nYou Lose\nᇂ_ᇂ Oh, too bad. Better luck next time. You were so close ", 
                            "\n \(♡´౪<♡)/ YOU WON \(♡´౪<♡)/ \n", 
                            "You can still win this...", 
                            "\n\n\nYou're still going this is sad. (ノ-_-)ノ ミ ┴┴",
                           "\n\n\n I would be on the floor. ( ＞Д＜ )ゝ",
                           "\n\n\n This... You... Wow this is Amazing! Congrats! (─‿‿─) ♡",
                           "\nYou Lose\n( ͡ಠ ͜ʖ ͡ಠ) I belive in you. You will get them next time.",
                           "\nIt's not over yet. d(>_･ )"]
        self.wins = [0,0]
        


    def quart (self):
        num = random.random()
        qu = round(num * 10)

        if (qu >= 5):
            self.quarter = 1
        else: 
            self.quarter = 0
        return self.quarter


    def dim (self):
        num = random.random()
        dim = round(num * 10)
        
        if (dim >= 5):
            self.dime = 1
        else: 
            self.dime = 0
        return self.dime
        

    def nick (self):
        num = random.random()
        nick = round(num * 10)
        if (nick >= 5):
            self.nickel = 1
        else: 
            self.nickel = 0
        return self.nickel

    def place(self):
        
        if (self.quarter == 1):
            q = self.sideUp[1]
        else: 
            q = self.sideUp[0]

        if (self.dime == 1):
            d = self.sideUp[1]
        else: 
            d = self.sideUp[0]

        if (self.nickel == 1):
            n = self.sideUp[1]
        else: 
            n = self.sideUp[0]

        time.sleep(0.5)
        print("Quarter is", q) 
        time.sleep(0.5)
        print("Dime is", d) 
        time.sleep(0.5)
        print("Nickel is", n)
        time.sleep(0.5)

        return 0

    def toss (self):
        
        if (self.quarter == 1):
            q = 0.250
        else: 
            q = 0.00

        if (self.dime == 1):
            d = 0.10
        else: 
            d = 0.00

        if (self.nickel == 1):
            n = 0.050
        else: 
            n = 0.00

        ans = n + q + d

        self.balances += ans

        return print("\nToss Amount: $", round(ans,3))

   
    
    def menu (self):


        print("Want to play?")
        print("The game is simple. You will toss three coins (quarter, dime, nickel) the goal is to get to a dollar.")

        x = input(" Ready? (Press any button to start)")

        while ((x != 'N') or (x != 'n')):

            Games = 0

            go = True
            balance = 0.00
            cnt = 0.00
            
            while (go == True):

                
                cont = input()
                print("\n")
                time.sleep(0.25) 
                print(".", end=' ') 
                time.sleep(0.25) 
                print(".", end=' ') 
                time.sleep(0.25) 
                print(".", end=' ')
                time.sleep(0.25) 
                print("Tossing")
                
                if (cont != None):
                    
                    self.quart()
                    self.dim()
                    self.nick()

                    self.place()
                    self.toss()

                

                if (self.balances == 1.00):
                    self.wins[1] += 1
                    name = self.Game_Goings[1]
                    
                   
                    
                elif (self.balances > 1.00):

                    n = random.random()
                    now = round(n * 10)
                    
                    if(now >= 5):
                        name = self.Game_Goings[0]
                    else:
                        name = self.Game_Goings[6]
                    
                    self.wins[0] += 1
                    
                elif (self.balances <= 0.99):

                    n = random.random()
                    now = round(n * 10)
                    
                    if(now >= 5):
                        name = self.Game_Goings[2]
                    else:
                        name = self.Game_Goings[7]

                if (self.balances >= 1.00):
                    go = False

                print(name, "\nOverall Balance: $", round(self.balances, 3), "\nPress Enter to continue")

                if (self.balances >= 1.00):
                    self.balances = 0.00

                Overall = self.wins[1] + self.wins[0]

                if (Overall == 10):
                    if (self.wins[1] <= self.wins[0]):
                        print(self.Game_Goings[3])
                if (Overall == 20):
                    if (self.wins[1] <= self.wins[0]):
                        print(self.Game_Goings[4])
                if (Overall == 5):
                        if (self.wins[1] > self.wins[0]):
                            print(self.Game_Goings[5])
                    

            

            x = input("\n\nWant to play again? (Press any button to continue or N to exit)")

            if (x == 'n' or x == 'N'):
                print("Games Win:", self.wins[1], " Games Loses: ", self.wins[0])
                
                return print("\nThank you for playing...\n\n\n\t｡^‿^｡")



if __name__ == '__main__':
    Game_Start = Coin() 
    Game_Start.menu()
# Out:
# Want to play?
# The game is simple. You will toss three coins the goal is to get to a dollar.
#  Ready? (Press any button to start)
# . . . Tossing
# Quarter is Heads
# Dime is Tails
# Nickel is Heads
#
# Toss Amount: $ 0.3
# You can still win this...
# Overall Balance: $ 0.3
# Press Enter to continue
# . . . Tossing
# Quarter is Tails
# Dime is Tails
# Nickel is Tails
#
# Toss Amount: $ 0.0
# You can still win this...
# Overall Balance: $ 0.3
# Press Enter to continue
# . . . Tossing
# Quarter is Tails
# Dime is Heads
# Nickel is Heads
#
# Toss Amount: $ 0.15
# You can still win this...
# Overall Balance: $ 0.45
# Press Enter to continue
# . . . Tossing
# Quarter is Tails
# Dime is Heads
# Nickel is Tails
#
# Toss Amount: $ 0.1
#
# It's not over yet. d(>_･ )
# Overall Balance: $ 0.55
# Press Enter to continue
# . . . Tossing
# Quarter is Heads
# Dime is Tails
# Nickel is Heads
#
# Toss Amount: $ 0.3
# You can still win this...
# Overall Balance: $ 0.85
# Press Enter to continue
# ...
